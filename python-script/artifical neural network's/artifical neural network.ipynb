# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
import torch
from torch import nn
from torch.utils.data import  DataLoader,SubsetRandomSampler 
import torch.optim as optim # Optimization package
from sklearn.model_selection import KFold
from sklearn.utils import shuffle
# Out:
# /Users/mawuliagamah/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# <p> helper functions and classes </p>

# %%
def see_data_stored(data_from_customDataFunction):
  x = print('\nFirst iteration of data set: ', next(iter(data_from_customDataFunction)), '\n') # Display text and label.
  y =print('Length of data set: ', len(data_from_customDataFunction), '\n')                  # Print how many items are in the data set
  #z = print('Entire data set: ', list(DataLoader(data_from_customDataFunction)), '\n')        # Print entire data set
  return x,y

# %% [markdown]
# ### Prepare data

# %% [markdown]
# <p> LOAD LALONDE DATASET </p>

# %%
'''
Load the two datasets.
nsw = Male sub sample of treated and control units as used by Lalonde.
nswre74  = Further subsample extracted by Dehejia and Wahba (1999) which includes information on earnings in 1974 (re74)

'''
nsw = pd.read_csv("/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/datasets/nsw_featureTransformed.csv")
nswre74 = pd.read_csv("/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/datasets/nswre74_featureTransformed.csv")

#Shuffle data sets 
nswre74_pd_df = shuffle(nswre74).reset_index(drop=True)
nsw_pd_df = shuffle(nsw).reset_index(drop=True)

# %% [markdown]
# <P> LOAD SIMULATED DATASET</P>

# %%
simulated_dataset = pd.read_csv('/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/datasets/simulated_experimental_dataset.csv')
simulated_dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# #### Data pre-processing for NN

# %%
# Subset dataset for ANN training 
nsw_subset1 = ['treat','ageboxcox','education','black','hispanic','married','nodegree','lnre75','lnre78']
nswre74_subset1 = ['treat','ageboxcox','education','black','hispanic','married','nodegree','lnre74','lnre75','lnre78']

nsw_pd_df = nsw_pd_df[nsw_subset1]
nswre74_pd_df= nswre74_pd_df[nswre74_subset1]

nsw_continuos_vars = ['ageboxcox','education','lnre75','lnre78'] 
nswre74_continuos_vars = ['ageboxcox','education','lnre74','lnre75','lnre78'] 

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# Standardize continous variables 
nsw_pd_df[nsw_continuos_vars] = sc.fit_transform(nsw_pd_df[nsw_continuos_vars])
nswre74_pd_df[nswre74_continuos_vars] = sc.fit_transform(nswre74_pd_df[nswre74_continuos_vars])

# %% [markdown]
# # Select variables for ML model
#
# # Original lalonde (1986) sample
# features_noRe74_df = nsw_pd_df.drop('treat', axis=1)
# target_noRe74_df = nsw_pd_df.iloc[:,0]
#
# features_noRe74_array = np.array(features_noRe74_df)
# target_noRe74_array = np.array(target_noRe74_df)
#
# FEATURES_noRe74 = torch.tensor(features_noRe74_array)
# TARGET_noRe74 = torch.tensor(target_noRe74_array).unsqueeze(1)
#
# # Dehejia and wahba (1999) sample
# features_df = nswre74_pd_df.drop('treat', axis=1)
# target_df = nswre74_pd_df.iloc[:,0]
#
# features_array = np.array(features_df)
# target_array = np.array(target_df)
#
# FEATURES_Re74 = torch.tensor(features_array)
# TARGET_Re74 = torch.tensor(target_array).unsqueeze(1)
# print(features_noRe74_array.shape,target_noRe74_df.shape)

# %% [markdown]
# #### Custom class for datasets

# %%
class CustomDataset:
  def __init__(self,features,target):    
    # load data
    self.features = features             
    self.target = target                
  
  def __len__(self):
    """
    Returns length of dataset.
    """

    return len(self.features)

  def __getitem__(self,idx):

    """
    Returns features and target with index idx.
    """
  
    features = self.features[idx]
    target = self.target[idx]
    return (features, target)

# %%
class CustomDataset:
  def __init__(self,features,target):    
    
    #import features and targets  
    self.features = features              
    self.target = target               
  
  def __len__(self):
    """
    Returns length of the dataset.
    """
    return len(self.features)

  def __getitem__(self,idx):
    """
    Returns features and target with index idx.
    """
    features = self.features[idx]
    target = self.target[idx]

    # convert data to array
    features_array = np.array(features)
    target_array = np.array(target)
    #convert to tensor 
    features = torch.tensor(features_array).float()
    target = torch.tensor(target_array).float()
    
    return (features, target)

# %% [markdown]
# ####  Construct NN

# %% [markdown]
# <p> set hyper parameters </p>

# %% [markdown]
# ### Model

# %%
# Define neural netowork class 
class threelayerNN(nn.Module):
    def __init__(self, num_features, num_classes, num_hidden_1, num_hidden_2,num_hidden_3,num_hidden_4,num_hidden_5):
        super(threelayerNN, self).__init__() 
       
        self.input_layer =  nn.Linear(num_features,num_hidden_1)                        
        self.hidden_layer1 = nn.Linear(num_hidden_1,num_hidden_2)                          
        self.hidden_layer2 =  nn.Linear(num_hidden_2, num_hidden_3) 
        self.hidden_layer3 =  nn.Linear(num_hidden_3, num_hidden_4) 
        self.hidden_layer4 =  nn.Linear(num_hidden_4, num_hidden_5)
        self.hidden_layer5 =  nn.Linear(num_hidden_5, num_classes) 
    
        # Activation functions
        self.relu_activation = nn.ReLU()    
        self.output_activation = nn.Sigmoid()
        #Drop out and batch normalisation 
        self.dropout = nn.Dropout(p=0.3)
        self.batchnorm1 = nn.BatchNorm1d(num_hidden_1)
        self.batchnorm2 = nn.BatchNorm1d(num_hidden_2)
        self.batchnorm3 = nn.BatchNorm1d(num_hidden_3)
        self.batchnorm4 = nn.BatchNorm1d(num_hidden_4)
        self.batchnorm5 = nn.BatchNorm1d(num_hidden_5)
    
    # Forward propogation method
    def forward(self, x):
        # input 
        x = self.input_layer(x)
        x = self.relu_activation(x)
        x = self.batchnorm1(x)
        x = self.dropout(x)
        # first hidden layer
        x = self.hidden_layer1(x)
        x = self.relu_activation(x)
        x = self.batchnorm2(x)
        x = self.dropout(x)
        # second hidden layer and output
        x = self.hidden_layer2(x)
        x = self.relu_activation(x)
        x = self.batchnorm3(x)
        x = self.dropout(x)
        x = self.hidden_layer3(x)
        x = self.relu_activation(x)
        x = self.batchnorm4(x)
        x = self.dropout(x)
        x = self.hidden_layer4(x)
        x = self.relu_activation(x)
        x = self.batchnorm5(x)
        x = self.dropout(x)
        x = self.hidden_layer5(x)
        x = self.output_activation(x)
        return x


class twoLayerNN(nn.Module):
    def __init__(self,num_features, num_classes, num_hidden_1, num_hidden_2):
        super(twoLayerNN, self).__init__() 
       
        self.input_layer =  nn.Linear(num_features,num_hidden_1)                        
        self.hidden_layer1 = nn.Linear(num_hidden_1,num_hidden_2)                          
        self.out_layer =  nn.Linear(num_hidden_2, num_classes) 

        # Activation functions
        self.relu_activation = nn.ReLU()    
        self.output_activation = nn.Sigmoid()
        #Drop out and batch normalisation 
        self.dropout = nn.Dropout(p=0.35)
        self.batchnorm1 = nn.BatchNorm1d(num_hidden_1)
        self.batchnorm2 = nn.BatchNorm1d(num_hidden_2)

    # Forward propogation method
    def forward(self, inputs):
        x = self.relu_activation(self.input_layer(inputs))
        x = self.batchnorm1(x)
        x = self.relu_activation(self.hidden_layer1(x))
        x = self.batchnorm2(x)
        x = self.dropout(x)
        x = self.output_activation(self.out_layer(x))
        return x

    def compute_l1_loss(self, w):
      return torch.abs(w).sum()

class ONELayerNN(nn.Module):
    def __init__(self,num_features, num_classes, num_hidden_1):
        super(ONELayerNN, self).__init__() 
       
        self.input_layer =  nn.Linear(num_features,num_hidden_1)                                               
        self.out_layer =  nn.Linear(num_hidden_1, num_classes) 

        # Activation functions
        self.relu_activation = nn.ReLU()    
        self.output_activation = nn.Sigmoid()
        #Drop out and batch normalisation 
        self.dropout = nn.Dropout(p=0.2)
        self.batchnorm1 = nn.BatchNorm1d(num_hidden_1)

    # Forward propogation method
    def forward(self, inputs):
        x = self.relu_activation(self.input_layer(inputs))
        x = self.batchnorm1(x)
        x = self.dropout(x)
        x = self.output_activation(self.out_layer(x))
        return x

    def compute_l1_loss(self, w):
      return torch.abs(w).sum()      

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# <p> NN helper functions </p>

# %%
# Function to reset model weights 
def reset_weights(m):
  '''
    Try resetting model weights to avoid
    weight leakage.
  '''
  for layer in m.children():
   if hasattr(layer, 'reset_parameters'):
    #print(f'Reset trainable parameters of layer = {layer}')
    layer.reset_parameters()

# %%
# Function to initialise model weights 
def initialize_weights(m):
    classname = m.__class__.__name__
    # For every linear layer in the mdoel   
    if classname.find('Linear') != -1:
     n = m.in_features
     y = 1.0/np.sqrt(n)
     m.weight.data.uniform_(-y, y)
     m.bias.data.fill_(0)

# %% [markdown]
# ### K-fold cross validation

# %% [markdown]
# <p> Initial settings <p>

# %%
from sklearn.model_selection import StratifiedKFold
from torchsampler import ImbalancedDatasetSampler
# Set model hyper parameters 
NUM_FEATURES = FEATURES_noRe74.shape[1]
NUM_HIDDEN_1 = 5
NUM_HIDDEN_2 = 5
NUM_HIDDEN_3 = 15
NUM_HIDDEN_4 = 15 
NUM_HIDDEN_5 = 15          
NUM_CLASSES = 1
NUM_EPOCHS = 1000
BATCH_SIZE =  64

LEARNING_RATE = 0.001

# training configuration options  
K_FOLDS = 5     
splits = KFold(n_splits=K_FOLDS,shuffle=True,random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter notebooks/artifical neural network.ipynb Cell 24 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000023?line=1'>2</a> from torchsampler import ImbalancedDatasetSampler
#       <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000023?line=2'>3</a> # Set model hyper parameters
# ----> <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000023?line=3'>4</a> NUM_FEATURES = FEATURES_noRe74.shape[1]
#       <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000023?line=4'>5</a> NUM_HIDDEN_1 = 5
#       <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000023?line=5'>6</a> NUM_HIDDEN_2 = 5
#
# NameError: name 'FEATURES_noRe74' is not defined

# %%
# Dictionaries to store results  
validation_accuracy_dict = {}      
validation_loss_dict = {}
training_accuracy_dict = {}
training_loss_dict = {}
foldperf = {}
acc_per_epoch = {}
fold_validation_accuracy = {}

# %% [markdown]
# ### K-FOLD Cross validation

# %%
dataset = CustomDataset(features = FEATURES_noRe74,target = TARGET_noRe74)

# %%
# set seed
torch.manual_seed(1)
print("==========  start =============")  
for fold, (train_ids, test_ids) in enumerate(splits.split(np.arange(len(dataset)))):    
#for fold, (train_ids, test_ids) in enumerate(splits.split(FEATURES_noRe74,TARGET_noRe74)):

    """  
    Sample elements randomly from a given list of ids, no replacement.
    """
    
    train_subsampler = SubsetRandomSampler(train_ids)
    test_subsampler = SubsetRandomSampler(test_ids)
    # Define data loaders for training and testing data in this fold
    
    trainloader = DataLoader(dataset,  batch_size=BATCH_SIZE, sampler=train_subsampler)
    testloader = DataLoader(dataset,batch_size=BATCH_SIZE, sampler=test_subsampler)

    # Instanstiate model 
    #model = threelayerNN(num_features = NUM_FEATURES,num_classes  = NUM_CLASSES, num_hidden_1 = NUM_HIDDEN_1,num_hidden_2 = NUM_HIDDEN_2,num_hidden_3 = NUM_HIDDEN_3,
    #num_hidden_4 = NUM_HIDDEN_4,num_hidden_5 = NUM_HIDDEN_5)
    model = twoLayerNN(num_features = NUM_FEATURES,num_classes  = NUM_CLASSES, num_hidden_1 = NUM_HIDDEN_1,num_hidden_2 = NUM_HIDDEN_2)
    model.to(device)
    # Reset weights 
    model.apply(reset_weights)
    model.apply(initialize_weights)
    #Initialise optimiser and loss function 
    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.BCEWithLogitsLoss()

    metrics = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

    # Run training over nuber of epochs  
    for epoch in range(0, NUM_EPOCHS):
        # Training variables 
        running_training_loss = 0.0
        total_training_samples = 0 
        train_correct = 0
        train_accuracy = 0
        total_validation_samples = 0 
        running_validation_loss = 0.0
        val_correct = 0
        validation_acc = 0
        #set model to training mode
        model.train()
        print('==========  Training ==========') 
        for idx, (features,target) in enumerate(trainloader,start = 0):       # Iterate over the DataLoader for training data

            # GET DATA  
            target_tensor = target
            train_features = features.float().to(device)
            train_target = target.float().to(device) 
            train_outputs = model(train_features)
            # COMPUTE LOSS
            loss = criterion(train_outputs , train_target)

             # ZERO PARAMETER GRADIENTS  
            optimizer.zero_grad()
            loss.backward()
            # UPDATE MODEL PARAMETERS
            optimizer.step()

            # ========== TRAINING LOG ========== #

            #calculate training accuracy
            # At the completion of each epoch , store train losses 
            train_prediction = (train_outputs >= 0.5).type(torch.uint8) 
            running_training_loss += loss.item()*train_features.size(0)
            train_correct += (train_prediction == train_target).numpy().sum()
 
            if epoch == NUM_EPOCHS:
                # Save the model afer each fold 
                save_path = f'/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter notebooks/ANN models/model-fold-{fold}.pth'
                #torch.save(model.state_dict(), '/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter notebooks/k_cross_ANN.pt')
                torch.save(model.state_dict(), save_path)
        
        # STORE AND LOG TRAINING INFORMATION
        train_accuracy = train_correct/len(trainloader.sampler)*100
        training_accuracy_dict[(fold,epoch)] = train_accuracy.item()
        avg_loss = running_training_loss / len(trainloader.sampler)
        training_loss_dict[(fold,epoch)] = avg_loss
        print(f'Fold: {fold}'f' | Epoc: {epoch+1}/{NUM_EPOCHS} 'f' | Training Loss: {avg_loss:.4f}'f'| Training accuracy: {train_accuracy:.2f}')
    
        # Evaluate the model 
        with torch.no_grad():
            model.eval()
            print('==========  Validating ==========') 
            for idx, (features,target) in enumerate(testloader): # Iterate over the test data and generate predictions
                
                val_features = features.float().to(device)
                val_targets = target.float().to(device) 
                val_outputs = model(val_features)

                loss_validation = criterion(val_outputs , val_targets)

                # ========== VALIDATION LOG ========== # 

                prediction = (val_outputs >= 0.5).type(torch.uint8) 
                running_validation_loss += loss_validation.item()*val_features.size(0)
                val_correct += (prediction == val_targets).numpy().sum()

            # STORE AND LOG VALIDATION INFORMATION 
            validation_acc = val_correct/len(testloader.sampler)*100
            validation_accuracy_dict[(fold,epoch)]  = validation_acc.item()
            avg_val_loss = running_validation_loss / len(testloader.sampler)
            validation_loss_dict[(fold,epoch)] = avg_val_loss
            print(f'Fold: {fold}'f' | Epoc: {epoch+1}/{NUM_EPOCHS} | Valid Loss: {avg_val_loss:.2f}'f'| Validation accuracy: {validation_acc:.2f}')
            # * * * * * * * * * * * * * * * * * * * * * * * * * * * * 



validation_accuracy_list = list(validation_accuracy_dict.values())
average_validation_acc = np.sum(validation_accuracy_list)/len(validation_accuracy_list)
training_accuracy_list = list(training_accuracy_dict.values())
average_training_acc = np.sum(training_accuracy_list)/len(training_accuracy_list)

print(f'K-FOLD CROSS VALIDATION RESULTS FOR {K_FOLDS} FOLDS')

print(f'AVG valdiation acc: {average_validation_acc:.2f}| 'f'AVG training acc: {average_training_acc:.2f}')
# Out:
# ==========  start =============
# ==========  Training ==========
# Fold: 0 | Epoc: 1/1000  | Training Loss: 0.7801| Training accuracy: 50.63
# ==========  Validating ==========
# Fold: 0 | Epoc: 1/1000 | Valid Loss: 0.74| Validation accuracy: 52.52
# ==========  Training ==========
# Fold: 0 | Epoc: 2/1000  | Training Loss: 0.7808| Training accuracy: 50.09
# ==========  Validating ==========
# Fold: 0 | Epoc: 2/1000 | Valid Loss: 0.74| Validation accuracy: 51.80
# ==========  Training ==========
# Fold: 0 | Epoc: 3/1000  | Training Loss: 0.7775| Training accuracy: 50.81
# ==========  Validating ==========
# Fold: 0 | Epoc: 3/1000 | Valid Loss: 0.74| Validation accuracy: 53.24
# ==========  Training ==========
# Fold: 0 | Epoc: 4/1000  | Training Loss: 0.7778| Training accuracy: 50.81
# ==========  Validating ==========
# Fold: 0 | Epoc: 4/1000 | Valid Loss: 0.74| Validation accuracy: 51.80
# ==========  Training ==========
# Fold: 0 | Epoc: 5/1000  | Training Loss: 0.7726| Training accuracy: 53.16
# ==========  Validating ==========
# Fold: 0 | Epoc: 5/1000 | Valid Loss: 0.74| Validation accuracy: 49.64
# ==========  Training ==========
# Fold: 0 | Epoc: 6/1000  | Training Loss: 0.7717| Training accuracy: 52.62
# ==========  Validating ==========
# Fold: 0 | Epoc: 6/1000 | Valid Loss: 0.74| Validation accuracy: 51.08
# ==========  Training ==========
# Fold: 0 | Epoc: 7/1000  | Training Loss: 0.7705| Training accuracy: 54.25
# ==========  Validating ==========
# Fold: 0 | Epoc: 7/1000 | Valid Loss: 0.74| Validation accuracy: 51.80
# ==========  Training ==========
# Fold: 0 | Epoc: 8/1000  | Training Loss: 0.7677| Training accuracy: 55.52
# ==========  Validating ==========
# Fold: 0 | Epoc: 8/1000 | Valid Loss: 0.74| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 9/1000  | Training Loss: 0.7678| Training accuracy: 54.97
# ==========  Validating ==========
# Fold: 0 | Epoc: 9/1000 | Valid Loss: 0.74| Validation accuracy: 53.24
# ==========  Training ==========
# Fold: 0 | Epoc: 10/1000  | Training Loss: 0.7633| Training accuracy: 56.60
# ==========  Validating ==========
# Fold: 0 | Epoc: 10/1000 | Valid Loss: 0.74| Validation accuracy: 52.52
# ==========  Training ==========
# Fold: 0 | Epoc: 11/1000  | Training Loss: 0.7645| Training accuracy: 56.42
# ==========  Validating ==========
# Fold: 0 | Epoc: 11/1000 | Valid Loss: 0.74| Validation accuracy: 52.52
# ==========  Training ==========
# Fold: 0 | Epoc: 12/1000  | Training Loss: 0.7630| Training accuracy: 56.96
# ==========  Validating ==========
# Fold: 0 | Epoc: 12/1000 | Valid Loss: 0.74| Validation accuracy: 50.36
# ==========  Training ==========
# Fold: 0 | Epoc: 13/1000  | Training Loss: 0.7607| Training accuracy: 57.50
# ==========  Validating ==========
# Fold: 0 | Epoc: 13/1000 | Valid Loss: 0.73| Validation accuracy: 49.64
# ==========  Training ==========
# Fold: 0 | Epoc: 14/1000  | Training Loss: 0.7597| Training accuracy: 56.60
# ==========  Validating ==========
# Fold: 0 | Epoc: 14/1000 | Valid Loss: 0.73| Validation accuracy: 50.36
# ==========  Training ==========
# Fold: 0 | Epoc: 15/1000  | Training Loss: 0.7533| Training accuracy: 59.13
# ==========  Validating ==========
# Fold: 0 | Epoc: 15/1000 | Valid Loss: 0.73| Validation accuracy: 51.08
# ==========  Training ==========
# Fold: 0 | Epoc: 16/1000  | Training Loss: 0.7557| Training accuracy: 58.41
# ==========  Validating ==========
# Fold: 0 | Epoc: 16/1000 | Valid Loss: 0.73| Validation accuracy: 50.36
# ==========  Training ==========
# Fold: 0 | Epoc: 17/1000  | Training Loss: 0.7564| Training accuracy: 57.69
# ==========  Validating ==========
# Fold: 0 | Epoc: 17/1000 | Valid Loss: 0.73| Validation accuracy: 50.36
# ==========  Training ==========
# Fold: 0 | Epoc: 18/1000  | Training Loss: 0.7510| Training accuracy: 58.23
# ==========  Validating ==========
# Fold: 0 | Epoc: 18/1000 | Valid Loss: 0.73| Validation accuracy: 49.64
# ==========  Training ==========
# Fold: 0 | Epoc: 19/1000  | Training Loss: 0.7491| Training accuracy: 60.04
# ==========  Validating ==========
# Fold: 0 | Epoc: 19/1000 | Valid Loss: 0.73| Validation accuracy: 50.36
# ==========  Training ==========
# Fold: 0 | Epoc: 20/1000  | Training Loss: 0.7490| Training accuracy: 58.05
# ==========  Validating ==========
# Fold: 0 | Epoc: 20/1000 | Valid Loss: 0.73| Validation accuracy: 51.08
# ==========  Training ==========
# Fold: 0 | Epoc: 21/1000  | Training Loss: 0.7489| Training accuracy: 59.49
# ==========  Validating ==========
# Fold: 0 | Epoc: 21/1000 | Valid Loss: 0.73| Validation accuracy: 51.08
# ==========  Training ==========
# Fold: 0 | Epoc: 22/1000  | Training Loss: 0.7462| Training accuracy: 58.23
# ==========  Validating ==========
# Fold: 0 | Epoc: 22/1000 | Valid Loss: 0.73| Validation accuracy: 51.08
# ==========  Training ==========
# Fold: 0 | Epoc: 23/1000  | Training Loss: 0.7457| Training accuracy: 60.04
# ==========  Validating ==========
# Fold: 0 | Epoc: 23/1000 | Valid Loss: 0.73| Validation accuracy: 51.80
# ==========  Training ==========
# Fold: 0 | Epoc: 24/1000  | Training Loss: 0.7455| Training accuracy: 58.59
# ==========  Validating ==========
# Fold: 0 | Epoc: 24/1000 | Valid Loss: 0.73| Validation accuracy: 51.08
# ==========  Training ==========
# Fold: 0 | Epoc: 25/1000  | Training Loss: 0.7463| Training accuracy: 57.50
# ==========  Validating ==========
# Fold: 0 | Epoc: 25/1000 | Valid Loss: 0.73| Validation accuracy: 52.52
# ==========  Training ==========
# Fold: 0 | Epoc: 26/1000  | Training Loss: 0.7414| Training accuracy: 60.22
# ==========  Validating ==========
# Fold: 0 | Epoc: 26/1000 | Valid Loss: 0.73| Validation accuracy: 51.80
# ==========  Training ==========
# Fold: 0 | Epoc: 27/1000  | Training Loss: 0.7444| Training accuracy: 59.13
# ==========  Validating ==========
# Fold: 0 | Epoc: 27/1000 | Valid Loss: 0.72| Validation accuracy: 50.36
# ==========  Training ==========
# Fold: 0 | Epoc: 28/1000  | Training Loss: 0.7398| Training accuracy: 59.31
# ==========  Validating ==========
# Fold: 0 | Epoc: 28/1000 | Valid Loss: 0.72| Validation accuracy: 51.80
# ==========  Training ==========
# Fold: 0 | Epoc: 29/1000  | Training Loss: 0.7450| Training accuracy: 58.77
# ==========  Validating ==========
# Fold: 0 | Epoc: 29/1000 | Valid Loss: 0.72| Validation accuracy: 52.52
# ==========  Training ==========
# Fold: 0 | Epoc: 30/1000  | Training Loss: 0.7403| Training accuracy: 57.87
# ==========  Validating ==========
# Fold: 0 | Epoc: 30/1000 | Valid Loss: 0.72| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 31/1000  | Training Loss: 0.7401| Training accuracy: 59.13
# ==========  Validating ==========
# Fold: 0 | Epoc: 31/1000 | Valid Loss: 0.72| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 32/1000  | Training Loss: 0.7369| Training accuracy: 60.04
# ==========  Validating ==========
# Fold: 0 | Epoc: 32/1000 | Valid Loss: 0.72| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 33/1000  | Training Loss: 0.7344| Training accuracy: 58.95
# ==========  Validating ==========
# Fold: 0 | Epoc: 33/1000 | Valid Loss: 0.71| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 34/1000  | Training Loss: 0.7312| Training accuracy: 58.95
# ==========  Validating ==========
# Fold: 0 | Epoc: 34/1000 | Valid Loss: 0.71| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 35/1000  | Training Loss: 0.7264| Training accuracy: 61.12
# ==========  Validating ==========
# Fold: 0 | Epoc: 35/1000 | Valid Loss: 0.71| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 36/1000  | Training Loss: 0.7320| Training accuracy: 59.67
# ==========  Validating ==========
# Fold: 0 | Epoc: 36/1000 | Valid Loss: 0.71| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 37/1000  | Training Loss: 0.7282| Training accuracy: 60.94
# ==========  Validating ==========
# Fold: 0 | Epoc: 37/1000 | Valid Loss: 0.71| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 38/1000  | Training Loss: 0.7279| Training accuracy: 60.58
# ==========  Validating ==========
# Fold: 0 | Epoc: 38/1000 | Valid Loss: 0.71| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 39/1000  | Training Loss: 0.7289| Training accuracy: 61.12
# ==========  Validating ==========
# Fold: 0 | Epoc: 39/1000 | Valid Loss: 0.71| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 40/1000  | Training Loss: 0.7261| Training accuracy: 61.12
# ==========  Validating ==========
# Fold: 0 | Epoc: 40/1000 | Valid Loss: 0.71| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 41/1000  | Training Loss: 0.7256| Training accuracy: 60.76
# ==========  Validating ==========
# Fold: 0 | Epoc: 41/1000 | Valid Loss: 0.71| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 42/1000  | Training Loss: 0.7259| Training accuracy: 60.94
# ==========  Validating ==========
# Fold: 0 | Epoc: 42/1000 | Valid Loss: 0.71| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 43/1000  | Training Loss: 0.7220| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 43/1000 | Valid Loss: 0.71| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 44/1000  | Training Loss: 0.7207| Training accuracy: 60.94
# ==========  Validating ==========
# Fold: 0 | Epoc: 44/1000 | Valid Loss: 0.71| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 45/1000  | Training Loss: 0.7180| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 45/1000 | Valid Loss: 0.71| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 46/1000  | Training Loss: 0.7216| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 46/1000 | Valid Loss: 0.71| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 47/1000  | Training Loss: 0.7116| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 47/1000 | Valid Loss: 0.71| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 48/1000  | Training Loss: 0.7234| Training accuracy: 60.94
# ==========  Validating ==========
# Fold: 0 | Epoc: 48/1000 | Valid Loss: 0.71| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 49/1000  | Training Loss: 0.7170| Training accuracy: 60.58
# ==========  Validating ==========
# Fold: 0 | Epoc: 49/1000 | Valid Loss: 0.71| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 50/1000  | Training Loss: 0.7198| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 50/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 51/1000  | Training Loss: 0.7174| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 51/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 52/1000  | Training Loss: 0.7147| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 52/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 53/1000  | Training Loss: 0.7151| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 53/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 54/1000  | Training Loss: 0.7130| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 54/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 55/1000  | Training Loss: 0.7108| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 55/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 56/1000  | Training Loss: 0.7156| Training accuracy: 61.12
# ==========  Validating ==========
# Fold: 0 | Epoc: 56/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 57/1000  | Training Loss: 0.7092| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 57/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 58/1000  | Training Loss: 0.7106| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 58/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 59/1000  | Training Loss: 0.7119| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 59/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 60/1000  | Training Loss: 0.7129| Training accuracy: 60.76
# ==========  Validating ==========
# Fold: 0 | Epoc: 60/1000 | Valid Loss: 0.70| Validation accuracy: 53.24
# ==========  Training ==========
# Fold: 0 | Epoc: 61/1000  | Training Loss: 0.7099| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 61/1000 | Valid Loss: 0.70| Validation accuracy: 53.24
# ==========  Training ==========
# Fold: 0 | Epoc: 62/1000  | Training Loss: 0.7073| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 62/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 63/1000  | Training Loss: 0.7103| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 63/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 64/1000  | Training Loss: 0.7086| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 64/1000 | Valid Loss: 0.70| Validation accuracy: 53.24
# ==========  Training ==========
# Fold: 0 | Epoc: 65/1000  | Training Loss: 0.7070| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 65/1000 | Valid Loss: 0.70| Validation accuracy: 53.96
# ==========  Training ==========
# Fold: 0 | Epoc: 66/1000  | Training Loss: 0.7074| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 66/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 67/1000  | Training Loss: 0.7073| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 67/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 68/1000  | Training Loss: 0.7064| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 68/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 69/1000  | Training Loss: 0.7084| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 69/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 70/1000  | Training Loss: 0.7038| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 70/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 71/1000  | Training Loss: 0.7064| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 71/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 72/1000  | Training Loss: 0.7018| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 72/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 73/1000  | Training Loss: 0.7077| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 73/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 74/1000  | Training Loss: 0.7030| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 74/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 75/1000  | Training Loss: 0.7029| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 75/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 76/1000  | Training Loss: 0.6996| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 76/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 77/1000  | Training Loss: 0.7024| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 77/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 78/1000  | Training Loss: 0.7049| Training accuracy: 61.30
# ==========  Validating ==========
# Fold: 0 | Epoc: 78/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 79/1000  | Training Loss: 0.7034| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 79/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 80/1000  | Training Loss: 0.7034| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 80/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 81/1000  | Training Loss: 0.7027| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 81/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 82/1000  | Training Loss: 0.6995| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 82/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 83/1000  | Training Loss: 0.6979| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 83/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 84/1000  | Training Loss: 0.6998| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 84/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 85/1000  | Training Loss: 0.6986| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 85/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 86/1000  | Training Loss: 0.7021| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 86/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 87/1000  | Training Loss: 0.6991| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 87/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 88/1000  | Training Loss: 0.7000| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 88/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 89/1000  | Training Loss: 0.7015| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 89/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 90/1000  | Training Loss: 0.6937| Training accuracy: 64.01
# ==========  Validating ==========
# Fold: 0 | Epoc: 90/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 91/1000  | Training Loss: 0.6985| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 91/1000 | Valid Loss: 0.70| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 92/1000  | Training Loss: 0.6985| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 92/1000 | Valid Loss: 0.70| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 93/1000  | Training Loss: 0.6994| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 93/1000 | Valid Loss: 0.70| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 94/1000  | Training Loss: 0.6994| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 94/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 95/1000  | Training Loss: 0.6975| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 95/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 96/1000  | Training Loss: 0.6986| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 96/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 97/1000  | Training Loss: 0.6977| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 97/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 98/1000  | Training Loss: 0.6994| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 98/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 99/1000  | Training Loss: 0.6987| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 99/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 100/1000  | Training Loss: 0.6959| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 100/1000 | Valid Loss: 0.70| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 101/1000  | Training Loss: 0.6999| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 101/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 102/1000  | Training Loss: 0.6964| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 102/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 103/1000  | Training Loss: 0.6961| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 103/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 104/1000  | Training Loss: 0.6972| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 104/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 105/1000  | Training Loss: 0.6990| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 105/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 106/1000  | Training Loss: 0.6984| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 106/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 107/1000  | Training Loss: 0.6991| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 107/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 108/1000  | Training Loss: 0.6977| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 108/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 109/1000  | Training Loss: 0.6981| Training accuracy: 61.66
# ==========  Validating ==========
# Fold: 0 | Epoc: 109/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 110/1000  | Training Loss: 0.6990| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 110/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 111/1000  | Training Loss: 0.6999| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 111/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 112/1000  | Training Loss: 0.6945| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 112/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 113/1000  | Training Loss: 0.6976| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 113/1000 | Valid Loss: 0.70| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 114/1000  | Training Loss: 0.6971| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 114/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 115/1000  | Training Loss: 0.6961| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 115/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 116/1000  | Training Loss: 0.6963| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 116/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 117/1000  | Training Loss: 0.6944| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 117/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 118/1000  | Training Loss: 0.6965| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 118/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 119/1000  | Training Loss: 0.6984| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 119/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 120/1000  | Training Loss: 0.6969| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 120/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 121/1000  | Training Loss: 0.6969| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 121/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 122/1000  | Training Loss: 0.6972| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 122/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 123/1000  | Training Loss: 0.6926| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 123/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 124/1000  | Training Loss: 0.6908| Training accuracy: 63.29
# ==========  Validating ==========
# Fold: 0 | Epoc: 124/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 125/1000  | Training Loss: 0.6940| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 125/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 126/1000  | Training Loss: 0.6952| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 126/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 127/1000  | Training Loss: 0.6984| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 127/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 128/1000  | Training Loss: 0.6973| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 128/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 129/1000  | Training Loss: 0.6995| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 129/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 130/1000  | Training Loss: 0.6939| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 130/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 131/1000  | Training Loss: 0.6958| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 131/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 132/1000  | Training Loss: 0.6926| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 132/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 133/1000  | Training Loss: 0.6959| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 133/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 134/1000  | Training Loss: 0.6926| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 134/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 135/1000  | Training Loss: 0.6950| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 135/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 136/1000  | Training Loss: 0.6989| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 136/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 137/1000  | Training Loss: 0.6927| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 137/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 138/1000  | Training Loss: 0.6944| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 138/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 139/1000  | Training Loss: 0.6923| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 139/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 140/1000  | Training Loss: 0.6958| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 140/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 141/1000  | Training Loss: 0.6910| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 141/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 142/1000  | Training Loss: 0.6936| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 142/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 143/1000  | Training Loss: 0.6955| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 143/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 144/1000  | Training Loss: 0.6987| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 144/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 145/1000  | Training Loss: 0.6930| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 145/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 146/1000  | Training Loss: 0.6937| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 146/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 147/1000  | Training Loss: 0.6938| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 147/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 148/1000  | Training Loss: 0.6900| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 148/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 149/1000  | Training Loss: 0.6938| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 149/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 150/1000  | Training Loss: 0.6925| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 150/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 151/1000  | Training Loss: 0.6896| Training accuracy: 63.47
# ==========  Validating ==========
# Fold: 0 | Epoc: 151/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 152/1000  | Training Loss: 0.6932| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 152/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 153/1000  | Training Loss: 0.6932| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 153/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 154/1000  | Training Loss: 0.6918| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 154/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 155/1000  | Training Loss: 0.6939| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 155/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 156/1000  | Training Loss: 0.6931| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 156/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 157/1000  | Training Loss: 0.6901| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 157/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 158/1000  | Training Loss: 0.6927| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 158/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 159/1000  | Training Loss: 0.6893| Training accuracy: 63.65
# ==========  Validating ==========
# Fold: 0 | Epoc: 159/1000 | Valid Loss: 0.69| Validation accuracy: 54.68
# ==========  Training ==========
# Fold: 0 | Epoc: 160/1000  | Training Loss: 0.6936| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 160/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 161/1000  | Training Loss: 0.6974| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 161/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 162/1000  | Training Loss: 0.6952| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 162/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 163/1000  | Training Loss: 0.6931| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 163/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 164/1000  | Training Loss: 0.6910| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 164/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 165/1000  | Training Loss: 0.6929| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 165/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 166/1000  | Training Loss: 0.6942| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 166/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 167/1000  | Training Loss: 0.6940| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 167/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 168/1000  | Training Loss: 0.6926| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 168/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 169/1000  | Training Loss: 0.6941| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 169/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 170/1000  | Training Loss: 0.6930| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 170/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 171/1000  | Training Loss: 0.6924| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 171/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 172/1000  | Training Loss: 0.6948| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 172/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 173/1000  | Training Loss: 0.6936| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 173/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 174/1000  | Training Loss: 0.6937| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 174/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 175/1000  | Training Loss: 0.6931| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 175/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 176/1000  | Training Loss: 0.6938| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 176/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 177/1000  | Training Loss: 0.6927| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 177/1000 | Valid Loss: 0.69| Validation accuracy: 55.40
# ==========  Training ==========
# Fold: 0 | Epoc: 178/1000  | Training Loss: 0.6902| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 178/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 179/1000  | Training Loss: 0.6921| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 179/1000 | Valid Loss: 0.69| Validation accuracy: 56.12
# ==========  Training ==========
# Fold: 0 | Epoc: 180/1000  | Training Loss: 0.6906| Training accuracy: 63.29
# ==========  Validating ==========
# Fold: 0 | Epoc: 180/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 181/1000  | Training Loss: 0.6957| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 181/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 182/1000  | Training Loss: 0.6944| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 182/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 183/1000  | Training Loss: 0.6926| Training accuracy: 63.29
# ==========  Validating ==========
# Fold: 0 | Epoc: 183/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 184/1000  | Training Loss: 0.6934| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 184/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 185/1000  | Training Loss: 0.6934| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 185/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 186/1000  | Training Loss: 0.6909| Training accuracy: 63.47
# ==========  Validating ==========
# Fold: 0 | Epoc: 186/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 187/1000  | Training Loss: 0.6902| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 187/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 188/1000  | Training Loss: 0.6928| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 188/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 189/1000  | Training Loss: 0.6913| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 189/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 190/1000  | Training Loss: 0.6913| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 190/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 191/1000  | Training Loss: 0.6914| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 191/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 192/1000  | Training Loss: 0.6923| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 192/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 193/1000  | Training Loss: 0.6936| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 193/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 194/1000  | Training Loss: 0.6904| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 194/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 195/1000  | Training Loss: 0.6887| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 195/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 196/1000  | Training Loss: 0.6921| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 196/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 197/1000  | Training Loss: 0.6930| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 197/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 198/1000  | Training Loss: 0.6913| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 198/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 199/1000  | Training Loss: 0.6947| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 199/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 200/1000  | Training Loss: 0.6905| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 200/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 201/1000  | Training Loss: 0.6906| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 201/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 202/1000  | Training Loss: 0.6936| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 202/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 203/1000  | Training Loss: 0.6923| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 203/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 204/1000  | Training Loss: 0.6928| Training accuracy: 62.93
# ==========  Validating ==========
# Fold: 0 | Epoc: 204/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 205/1000  | Training Loss: 0.6912| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 205/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 206/1000  | Training Loss: 0.6928| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 206/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 207/1000  | Training Loss: 0.6915| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 207/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 208/1000  | Training Loss: 0.6917| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 208/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 209/1000  | Training Loss: 0.6931| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 209/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 210/1000  | Training Loss: 0.6919| Training accuracy: 62.39
# ==========  Validating ==========
# Fold: 0 | Epoc: 210/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 211/1000  | Training Loss: 0.6898| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 211/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 212/1000  | Training Loss: 0.6938| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 212/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 213/1000  | Training Loss: 0.6949| Training accuracy: 61.48
# ==========  Validating ==========
# Fold: 0 | Epoc: 213/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 214/1000  | Training Loss: 0.6889| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 214/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 215/1000  | Training Loss: 0.6940| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 215/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 216/1000  | Training Loss: 0.6930| Training accuracy: 62.21
# ==========  Validating ==========
# Fold: 0 | Epoc: 216/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 217/1000  | Training Loss: 0.6904| Training accuracy: 63.11
# ==========  Validating ==========
# Fold: 0 | Epoc: 217/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 218/1000  | Training Loss: 0.6935| Training accuracy: 62.03
# ==========  Validating ==========
# Fold: 0 | Epoc: 218/1000 | Valid Loss: 0.69| Validation accuracy: 56.83
# ==========  Training ==========
# Fold: 0 | Epoc: 219/1000  | Training Loss: 0.6926| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 219/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 220/1000  | Training Loss: 0.6908| Training accuracy: 62.75
# ==========  Validating ==========
# Fold: 0 | Epoc: 220/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 221/1000  | Training Loss: 0.6909| Training accuracy: 63.29
# ==========  Validating ==========
# Fold: 0 | Epoc: 221/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 222/1000  | Training Loss: 0.6935| Training accuracy: 61.84
# ==========  Validating ==========
# Fold: 0 | Epoc: 222/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 223/1000  | Training Loss: 0.6900| Training accuracy: 62.57
# ==========  Validating ==========
# Fold: 0 | Epoc: 223/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 224/1000  | Training Loss: 0.6883| Training accuracy: 63.65
# ==========  Validating ==========
# Fold: 0 | Epoc: 224/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# Fold: 0 | Epoc: 225/1000  | Training Loss: 0.6904| Training accuracy: 63.47
# ==========  Validating ==========
# Fold: 0 | Epoc: 225/1000 | Valid Loss: 0.69| Validation accuracy: 57.55
# ==========  Training ==========
# ...
# ==========  Training ==========
# Fold: 4 | Epoc: 927/1000  | Training Loss: 0.6774| Training accuracy: 65.16
# ==========  Validating ==========
# Fold: 4 | Epoc: 927/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 928/1000  | Training Loss: 0.6725| Training accuracy: 66.25
# ==========  Validating ==========
# Fold: 4 | Epoc: 928/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 929/1000  | Training Loss: 0.6740| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 929/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 930/1000  | Training Loss: 0.6778| Training accuracy: 65.16
# ==========  Validating ==========
# Fold: 4 | Epoc: 930/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 931/1000  | Training Loss: 0.6731| Training accuracy: 65.70
# ==========  Validating ==========
# Fold: 4 | Epoc: 931/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 932/1000  | Training Loss: 0.6721| Training accuracy: 66.79
# ==========  Validating ==========
# Fold: 4 | Epoc: 932/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 933/1000  | Training Loss: 0.6714| Training accuracy: 66.43
# ==========  Validating ==========
# Fold: 4 | Epoc: 933/1000 | Valid Loss: 0.73| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 934/1000  | Training Loss: 0.6744| Training accuracy: 65.88
# ==========  Validating ==========
# Fold: 4 | Epoc: 934/1000 | Valid Loss: 0.73| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 935/1000  | Training Loss: 0.6730| Training accuracy: 66.61
# ==========  Validating ==========
# Fold: 4 | Epoc: 935/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 936/1000  | Training Loss: 0.6758| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 936/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 937/1000  | Training Loss: 0.6706| Training accuracy: 66.97
# ==========  Validating ==========
# Fold: 4 | Epoc: 937/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 938/1000  | Training Loss: 0.6780| Training accuracy: 65.16
# ==========  Validating ==========
# Fold: 4 | Epoc: 938/1000 | Valid Loss: 0.73| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 939/1000  | Training Loss: 0.6767| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 939/1000 | Valid Loss: 0.72| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 940/1000  | Training Loss: 0.6723| Training accuracy: 66.79
# ==========  Validating ==========
# Fold: 4 | Epoc: 940/1000 | Valid Loss: 0.72| Validation accuracy: 57.25
# ==========  Training ==========
# Fold: 4 | Epoc: 941/1000  | Training Loss: 0.6822| Training accuracy: 64.08
# ==========  Validating ==========
# Fold: 4 | Epoc: 941/1000 | Valid Loss: 0.72| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 942/1000  | Training Loss: 0.6739| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 942/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 943/1000  | Training Loss: 0.6749| Training accuracy: 65.70
# ==========  Validating ==========
# Fold: 4 | Epoc: 943/1000 | Valid Loss: 0.73| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 944/1000  | Training Loss: 0.6738| Training accuracy: 65.70
# ==========  Validating ==========
# Fold: 4 | Epoc: 944/1000 | Valid Loss: 0.73| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 945/1000  | Training Loss: 0.6718| Training accuracy: 66.43
# ==========  Validating ==========
# Fold: 4 | Epoc: 945/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 946/1000  | Training Loss: 0.6757| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 946/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 947/1000  | Training Loss: 0.6729| Training accuracy: 66.79
# ==========  Validating ==========
# Fold: 4 | Epoc: 947/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 948/1000  | Training Loss: 0.6742| Training accuracy: 65.88
# ==========  Validating ==========
# Fold: 4 | Epoc: 948/1000 | Valid Loss: 0.73| Validation accuracy: 53.62
# ==========  Training ==========
# Fold: 4 | Epoc: 949/1000  | Training Loss: 0.6757| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 949/1000 | Valid Loss: 0.73| Validation accuracy: 53.62
# ==========  Training ==========
# Fold: 4 | Epoc: 950/1000  | Training Loss: 0.6696| Training accuracy: 66.97
# ==========  Validating ==========
# Fold: 4 | Epoc: 950/1000 | Valid Loss: 0.74| Validation accuracy: 53.62
# ==========  Training ==========
# Fold: 4 | Epoc: 951/1000  | Training Loss: 0.6780| Training accuracy: 65.70
# ==========  Validating ==========
# Fold: 4 | Epoc: 951/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 952/1000  | Training Loss: 0.6758| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 952/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 953/1000  | Training Loss: 0.6748| Training accuracy: 66.25
# ==========  Validating ==========
# Fold: 4 | Epoc: 953/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 954/1000  | Training Loss: 0.6725| Training accuracy: 66.79
# ==========  Validating ==========
# Fold: 4 | Epoc: 954/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 955/1000  | Training Loss: 0.6757| Training accuracy: 65.88
# ==========  Validating ==========
# Fold: 4 | Epoc: 955/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 956/1000  | Training Loss: 0.6786| Training accuracy: 65.34
# ==========  Validating ==========
# Fold: 4 | Epoc: 956/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 957/1000  | Training Loss: 0.6833| Training accuracy: 62.82
# ==========  Validating ==========
# Fold: 4 | Epoc: 957/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 958/1000  | Training Loss: 0.6778| Training accuracy: 64.98
# ==========  Validating ==========
# Fold: 4 | Epoc: 958/1000 | Valid Loss: 0.73| Validation accuracy: 53.62
# ==========  Training ==========
# Fold: 4 | Epoc: 959/1000  | Training Loss: 0.6729| Training accuracy: 66.43
# ==========  Validating ==========
# Fold: 4 | Epoc: 959/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 960/1000  | Training Loss: 0.6754| Training accuracy: 65.88
# ==========  Validating ==========
# Fold: 4 | Epoc: 960/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 961/1000  | Training Loss: 0.6748| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 961/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 962/1000  | Training Loss: 0.6780| Training accuracy: 64.80
# ==========  Validating ==========
# Fold: 4 | Epoc: 962/1000 | Valid Loss: 0.72| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 963/1000  | Training Loss: 0.6712| Training accuracy: 66.43
# ==========  Validating ==========
# Fold: 4 | Epoc: 963/1000 | Valid Loss: 0.72| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 964/1000  | Training Loss: 0.6751| Training accuracy: 64.98
# ==========  Validating ==========
# Fold: 4 | Epoc: 964/1000 | Valid Loss: 0.72| Validation accuracy: 57.97
# ==========  Training ==========
# Fold: 4 | Epoc: 965/1000  | Training Loss: 0.6791| Training accuracy: 64.26
# ==========  Validating ==========
# Fold: 4 | Epoc: 965/1000 | Valid Loss: 0.72| Validation accuracy: 57.25
# ==========  Training ==========
# Fold: 4 | Epoc: 966/1000  | Training Loss: 0.6802| Training accuracy: 64.26
# ==========  Validating ==========
# Fold: 4 | Epoc: 966/1000 | Valid Loss: 0.72| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 967/1000  | Training Loss: 0.6776| Training accuracy: 65.34
# ==========  Validating ==========
# Fold: 4 | Epoc: 967/1000 | Valid Loss: 0.72| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 968/1000  | Training Loss: 0.6760| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 968/1000 | Valid Loss: 0.72| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 969/1000  | Training Loss: 0.6773| Training accuracy: 64.98
# ==========  Validating ==========
# Fold: 4 | Epoc: 969/1000 | Valid Loss: 0.73| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 970/1000  | Training Loss: 0.6739| Training accuracy: 66.61
# ==========  Validating ==========
# Fold: 4 | Epoc: 970/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 971/1000  | Training Loss: 0.6837| Training accuracy: 64.08
# ==========  Validating ==========
# Fold: 4 | Epoc: 971/1000 | Valid Loss: 0.72| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 972/1000  | Training Loss: 0.6755| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 972/1000 | Valid Loss: 0.72| Validation accuracy: 57.25
# ==========  Training ==========
# Fold: 4 | Epoc: 973/1000  | Training Loss: 0.6804| Training accuracy: 64.44
# ==========  Validating ==========
# Fold: 4 | Epoc: 973/1000 | Valid Loss: 0.72| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 974/1000  | Training Loss: 0.6716| Training accuracy: 66.79
# ==========  Validating ==========
# Fold: 4 | Epoc: 974/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 975/1000  | Training Loss: 0.6746| Training accuracy: 66.25
# ==========  Validating ==========
# Fold: 4 | Epoc: 975/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 976/1000  | Training Loss: 0.6832| Training accuracy: 64.08
# ==========  Validating ==========
# Fold: 4 | Epoc: 976/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 977/1000  | Training Loss: 0.6756| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 977/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 978/1000  | Training Loss: 0.6708| Training accuracy: 66.61
# ==========  Validating ==========
# Fold: 4 | Epoc: 978/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 979/1000  | Training Loss: 0.6697| Training accuracy: 67.33
# ==========  Validating ==========
# Fold: 4 | Epoc: 979/1000 | Valid Loss: 0.73| Validation accuracy: 53.62
# ==========  Training ==========
# Fold: 4 | Epoc: 980/1000  | Training Loss: 0.6758| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 980/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 981/1000  | Training Loss: 0.6709| Training accuracy: 66.79
# ==========  Validating ==========
# Fold: 4 | Epoc: 981/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 982/1000  | Training Loss: 0.6826| Training accuracy: 64.62
# ==========  Validating ==========
# Fold: 4 | Epoc: 982/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 983/1000  | Training Loss: 0.6783| Training accuracy: 65.16
# ==========  Validating ==========
# Fold: 4 | Epoc: 983/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 984/1000  | Training Loss: 0.6714| Training accuracy: 66.43
# ==========  Validating ==========
# Fold: 4 | Epoc: 984/1000 | Valid Loss: 0.73| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 985/1000  | Training Loss: 0.6737| Training accuracy: 66.25
# ==========  Validating ==========
# Fold: 4 | Epoc: 985/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 986/1000  | Training Loss: 0.6760| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 986/1000 | Valid Loss: 0.73| Validation accuracy: 53.62
# ==========  Training ==========
# Fold: 4 | Epoc: 987/1000  | Training Loss: 0.6751| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 987/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 988/1000  | Training Loss: 0.6728| Training accuracy: 66.79
# ==========  Validating ==========
# Fold: 4 | Epoc: 988/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 989/1000  | Training Loss: 0.6772| Training accuracy: 64.80
# ==========  Validating ==========
# Fold: 4 | Epoc: 989/1000 | Valid Loss: 0.73| Validation accuracy: 55.80
# ==========  Training ==========
# Fold: 4 | Epoc: 990/1000  | Training Loss: 0.6764| Training accuracy: 65.34
# ==========  Validating ==========
# Fold: 4 | Epoc: 990/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 991/1000  | Training Loss: 0.6722| Training accuracy: 65.34
# ==========  Validating ==========
# Fold: 4 | Epoc: 991/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 992/1000  | Training Loss: 0.6733| Training accuracy: 66.61
# ==========  Validating ==========
# Fold: 4 | Epoc: 992/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 993/1000  | Training Loss: 0.6768| Training accuracy: 65.52
# ==========  Validating ==========
# Fold: 4 | Epoc: 993/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 994/1000  | Training Loss: 0.6751| Training accuracy: 65.88
# ==========  Validating ==========
# Fold: 4 | Epoc: 994/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 995/1000  | Training Loss: 0.6739| Training accuracy: 66.06
# ==========  Validating ==========
# Fold: 4 | Epoc: 995/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 996/1000  | Training Loss: 0.6737| Training accuracy: 66.25
# ==========  Validating ==========
# Fold: 4 | Epoc: 996/1000 | Valid Loss: 0.73| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 997/1000  | Training Loss: 0.6752| Training accuracy: 65.34
# ==========  Validating ==========
# Fold: 4 | Epoc: 997/1000 | Valid Loss: 0.73| Validation accuracy: 56.52
# ==========  Training ==========
# Fold: 4 | Epoc: 998/1000  | Training Loss: 0.6764| Training accuracy: 65.88
# ==========  Validating ==========
# Fold: 4 | Epoc: 998/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# ==========  Training ==========
# Fold: 4 | Epoc: 999/1000  | Training Loss: 0.6714| Training accuracy: 66.43
# ==========  Validating ==========
# Fold: 4 | Epoc: 999/1000 | Valid Loss: 0.73| Validation accuracy: 54.35
# ==========  Training ==========
# Fold: 4 | Epoc: 1000/1000  | Training Loss: 0.6706| Training accuracy: 66.61
# ==========  Validating ==========
# Fold: 4 | Epoc: 1000/1000 | Valid Loss: 0.73| Validation accuracy: 55.07
# K-FOLD CROSS VALIDATION RESULTS FOR 5 FOLDS
# AVG valdiation acc: 58.46| AVG training acc: 63.11

# %%
validation_acc = list(validation_accuracy_dict.values())
average_validation_acc = np.sum(validation_acc)/len(validation_acc)
training_acc = list(training_accuracy_dict.values())
average_validation_acc = np.sum(training_acc)/len(training_acc)

# %% [markdown]
# ### Plot training summary

# %%
# Convert accuracy and loss dictionaries to lists 
validation_accurary_list = list(validation_accuracy_dict.values())
validation_loss_list = list(validation_loss_dict.values())
training_accuracy_list = list(training_accuracy_dict.values())
training_loss_list = list(training_loss_dict.values())

# %%
fig, ax = plt.subplots(figsize=(12,4))

ax.set_facecolor('gainsboro')
# Set boarder colour 
for spine in ax.spines:
    ax.spines[spine].set_color('black')
    ax.spines[spine].set_linewidth(1)

ax.grid(color='white', axis='x', linestyle='-', linewidth=1, alpha=0.5)
ax.grid(color='white', axis='y', linestyle='-', linewidth=1, alpha=0.5)

epochs_train = len(training_accuracy_list)
epochs_val = len(validation_accurary_list)

plt.plot(np.arange(1, epochs_train+1),training_accuracy_list, label='Training',color='magenta')
plt.plot(np.arange(1, epochs_val+1),validation_accurary_list, label='Validation',color='darkgreen')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot training and validation losses 

# Use to plots to clean up the presentation 
from tueplots import bundles 
from tueplots import figsizes
from tueplots import axes

# tueplots paramaters 
plt.rcParams.update(bundles.neurips2022())
plt.rcParams.update(axes.lines())
figsizes.neurips2021(nrows=3)["figure.figsize"]

plt.rcParams.update({"figure.dpi": 150})

fig, ax = plt.subplots(figsize=(12,4))

ax.set_facecolor('gainsboro')
# Set boarder colour 
for spine in ax.spines:
    ax.spines[spine].set_color('black')
    ax.spines[spine].set_linewidth(1)

ax.grid(color='white', axis='x', linestyle='-', linewidth=1, alpha=0.5)
ax.grid(color='white', axis='y', linestyle='-', linewidth=1, alpha=0.5)

ax.plot(training_loss_list, label='Training loss',color='magenta')
ax.plot(validation_loss_list, label='Validation loss',color = 'darkgreen')


ax.set_title(' Training and validation loss ')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')


ax.legend()


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
from sklearn.metrics import confusion_matrix

y_pred = []
y_true = []

dataset = CustomDataset(features = FEATURES_Re74,target = TARGET_Re74)
trainloader = DataLoader(dataset,  batch_size=BATCH_SIZE)


model = twoLayerNN(num_features = NUM_FEATURES,num_classes  = NUM_CLASSES, num_hidden_1 = NUM_HIDDEN_1,num_hidden_2 = NUM_HIDDEN_2)
model.apply(initialize_weights)
# iterate over test data
for idx,(features,target) in enumerate(trainloader,start = 0):
        features = features.float().to(device)
        target = target.float().to(device)
       
        output = model(features) # Feed Network
        outputs = ((output >= 0.5).type(torch.uint8)).numpy()
        y_pred.extend(outputs) # Save Prediction
        
        target = target.numpy()
        y_true.extend(target) # Save Truth


# constant for classes
classes = ('treat', 'control')

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)

df_cm = pd.DataFrame(cf_matrix/np.sum(cf_matrix) *100, index = [i for i in classes],columns = [i for i in classes])

plt.figure(figsize = (12,7))
sns.heatmap(df_cm, annot=True)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter notebooks/artifical neural network.ipynb Cell 46 in <cell line: 13>()
#      <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=13'>14</a> features = features.float().to(device)
#      <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=14'>15</a> target = target.float().to(device)
# ---> <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=16'>17</a> output = model(features) # Feed Network
#      <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=17'>18</a> outputs = ((output >= 0.5).type(torch.uint8)).numpy()
#      <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=18'>19</a> y_pred.extend(outputs) # Save Prediction
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# /Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter notebooks/artifical neural network.ipynb Cell 46 in twoLayerNN.forward(self, inputs)
#      <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=70'>71</a> def forward(self, inputs):
# ---> <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=71'>72</a>     x = self.relu_activation(self.input_layer(inputs))
#      <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=72'>73</a>     x = self.batchnorm1(x)
#      <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000048?line=73'>74</a>     x = self.relu_activation(self.hidden_layer1(x))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (64x9 and 8x5)

# %%
# Plot ROC curves 

outputs_pos = outputs == 1

ns_probs = [0 for _ in range(len(target))]

ns_auc = roc_auc_score(target, ns_probs)
lr_auc = roc_auc_score(target, outputs_pos)

ns_fpr, ns_tpr, _ = roc_curve(target, ns_probs)
lr_fpr, lr_tpr, _ = roc_curve(target, outputs_pos)

plt.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')
plt.plot(lr_fpr, lr_tpr, marker='.', label='nerual network')
# axis labels
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# show the legend
plt.legend()
# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter notebooks/artifical neural network.ipynb Cell 47 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000049?line=0'>1</a> # Plot ROC curves
# ----> <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000049?line=3'>4</a> outputs_pos = outputs == 1
#       <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000049?line=5'>6</a> ns_probs = [0 for _ in range(len(target))]
#       <a href='vscode-notebook-cell:/Users/mawuliagamah/gitprojects/causal_inference/causal_inference/Jupyter%20notebooks/artifical%20neural%20network.ipynb#ch0000049?line=7'>8</a> ns_auc = roc_auc_score(target, ns_probs)
#
# NameError: name 'outputs' is not defined

# %% [markdown]
# <p> Plot loss and accuracy </p>

# %% [markdown]
# ### Model training 2 - Train, Test Split, no Kfold , with imbalanced dalaloader

# %%
# Dictionaries to store results  
validation_accuracy_dict = {}      
validation_loss_dict = {}
training_accuracy_dict = {}
training_loss_dict = {}

train_precision_dict = {}
train_recall_dict = {}
train_f1_dict = {}
train_mse_dict = {}

test_precision_dict = {}
test_recall_dict = {}
test_f1_dict = {}
test_mse_dict = {}


foldperf = {}
acc_per_epoch = {}
fold_validation_accuracy = {}

# %%
nswre74_pd_df
# Out:
#      treat  ageboxcox  education  black  hispanic  married  nodegree  \
# 0        1   0.521243  -1.069522      1         0        0         1
# 1        1  -0.311408   1.140460      1         0        0         0
# 2        1  -0.116340   1.140460      1         0        0         0
# 3        0   0.652546   1.877121      1         0        0         0
# 4        0  -1.304893  -0.332862      1         0        0         1
# ..     ...        ...        ...    ...       ...      ...       ...
# 400      1  -1.017875  -0.332862      1         0        0         1
# 401      1  -0.759174   0.403799      1         0        0         1
# 402      1   0.379987   0.403799      1         0        0         1
# 403      1   0.774917  -0.332862      0         1        0         1
# 404      0  -0.311408  -0.332862      1         0        0         1
#
#        lnre74    lnre75    lnre78
# 0   -0.586159 -0.722547 -1.439254
# 1   -0.586159 -0.722547  0.986876
# 2   -0.586159 -0.722547 -1.439254
# 3   -0.586159 -0.722547 -1.439254
# 4    1.442672  1.425807 -1.439254
# ..        ...       ...       ...
# 400  1.681329  1.647461 -1.439254
# 401 -0.586159 -0.722547  0.604995
# 402 -0.586159 -0.722547  0.966970
# 403 -0.586159  1.750795  0.667238
# 404 -0.586159 -0.722547 -1.439254
#
# [405 rows x 10 columns]

# %%
# Subset dataset for ANN training 
nswre74_pd_df = nswre74_pd_df.sample(frac = 1,random_state=42).reset_index(drop=True)
nsw_pd_df = nsw_pd_df.sample(frac = 1,random_state=42).reset_index(drop=True)

nsw_subset1 = ['treat','ageboxcox','education','black','hispanic','married','nodegree','lnre75','lnre78']
nswre74_subset1 = ['treat','ageboxcox','education','black','hispanic','married','nodegree','lnre74','lnre75','lnre78']

nsw_pd_df = nsw_pd_df[nsw_subset1]
nswre74_pd_df= nswre74_pd_df[nswre74_subset1]

nsw_continuos_vars = ['ageboxcox','education','lnre75','lnre78'] 
nswre74_continuos_vars = ['ageboxcox','education','lnre74','lnre75','lnre78'] 

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

# Standardize continous variables 
nsw_pd_df[nsw_continuos_vars] = sc.fit_transform(nsw_pd_df[nsw_continuos_vars])
nswre74_pd_df[nswre74_continuos_vars] = sc.fit_transform(nswre74_pd_df[nswre74_continuos_vars])

# %%
from torchvision import datasets
from sklearn.model_selection import train_test_split
from torch.utils.data import WeightedRandomSampler

# Train test split 
train_dataset, test_dataset = train_test_split(nswre74_pd_df,  test_size=0.3, random_state=0)

# Calculate weights for class imbalance 
y_train_indices = train_dataset.index
y_train_indices
y_train = [nsw_pd_df.treat[i] for i in y_train_indices]

class_sample_count = np.array( [len(np.where(y_train == t)[0]) for t in np.unique(y_train)])

weight = 1. / class_sample_count * 100

samples_weight = np.array([weight[t] for t in y_train])
samples_weight = torch.from_numpy(samples_weight)
sampler = WeightedRandomSampler(samples_weight.type('torch.DoubleTensor'), len(samples_weight))

# Features and targets for train data
features_train_Re74_df = train_dataset.drop('treat', axis=1)
target_train_Re74_df = train_dataset.iloc[:,0]

features_train_Re74_array = np.array(features_train_Re74_df)
target_train_Re74_array = np.array(target_train_Re74_df)

FEATURES_TRAIN_Re74 = torch.tensor(features_train_Re74_array)
TARGET_TRAIN_Re74 = torch.tensor(target_train_Re74_array).unsqueeze(1)

# Features and targets for test data
features_test_Re74_df = test_dataset.drop('treat', axis=1)
target_test_Re74_df = test_dataset.iloc[:,0]

features_test_Re74_array = np.array(features_test_Re74_df)
target_test_Re74_array = np.array(target_test_Re74_df)

FEATURES_test_Re74 = torch.tensor(features_test_Re74_array)
TARGET_test_Re74 = torch.tensor(target_test_Re74_array).unsqueeze(1)

train_data = CustomDataset(features = FEATURES_TRAIN_Re74,target = TARGET_TRAIN_Re74)
test_data = CustomDataset(features = FEATURES_test_Re74,target = TARGET_test_Re74)

# %%
NUM_FEATURES = FEATURES_TRAIN_Re74.shape[1]
NUM_HIDDEN_1 = 5
NUM_HIDDEN_2 = 5
NUM_CLASSES = 1
NUM_EPOCHS = 200
BATCH_SIZE = 512
#BATCH_SIZE = 480
#BATCH_SIZE =  512
LEARNING_RATE = 0.001
#LEARNING_RATE = 0.0182
#WEIGHT_DECAY = 0.005
WEIGHT_DECAY = 0.0182

# %%
from torchsampler import ImbalancedDatasetSampler
import sklearn.metrics as metrics

trainloader = DataLoader(train_data,  batch_size=BATCH_SIZE,sampler=sampler)
testloader = DataLoader(test_data,batch_size=BATCH_SIZE)

# Instanstiate model 

model = twoLayerNN(num_features = NUM_FEATURES,num_classes  = NUM_CLASSES, num_hidden_1 = NUM_HIDDEN_1,num_hidden_2 = NUM_HIDDEN_2)
model.to(device)
# Reset weights 
model.apply(reset_weights)
model.apply(initialize_weights)
#Initialise optimiser and loss function 
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE,weight_decay=WEIGHT_DECAY)
criterion = nn.BCEWithLogitsLoss()

metrics = {'train_loss': [], 'test_loss': [],'train_acc':[],'test_acc':[]}

# %%
import warnings

# Functions for ANN training 
# def get loss each epoch 
def store_loss(loss,features,dataloader,running_loss,epoch,dataloader_id):
    if dataloader.__hash__() == dataloader_id:
        x = running_loss
        x += loss.item()*features.size(0)
        avg_loss = x / len(trainloader.sampler)
        training_loss_dict[(epoch)] = avg_loss
    else:
        x = running_loss
        x += loss.item()*features.size(0)
        avg_loss = x / len(trainloader.sampler)
        validation_loss_dict[(epoch)] = avg_loss


from sklearn import metrics

# def get metrics 
def store_metrics(pred,target,dataloader,epoch,dataloader_id):
    
    if dataloader.__hash__() == dataloader_id:
        # Precision
        precision = metrics.precision_score(target,pred)
        train_precision_dict[(epoch)] = precision
        # Recall
        recall = metrics.recall_score(target,pred)
        train_recall_dict[(epoch)] = recall
        # MSE 
        mse = metrics.mean_squared_error(target,pred)
        train_mse_dict[(epoch)] = mse
        # F1
        f1 = metrics.f1_score(target,pred)
        train_f1_dict[(epoch)] = f1
        warnings.filterwarnings('ignore')
    else:
        precision = metrics.precision_score(target,pred)
        test_precision_dict[(epoch)] = precision
        # Recall
        recall = metrics.recall_score(target,pred)
        test_recall_dict[(epoch)] = recall
        # MSE 
        mse = metrics.mean_squared_error(target,pred)
        test_mse_dict[(epoch)] = mse
        # F1
        f1 = metrics.f1_score(target,pred)
        test_f1_dict[(epoch)] = f1
        warnings.filterwarnings('ignore')

# %%
# Define train and test
def trainTestModel(train_loader, test_loader):
    
    model = twoLayerNN(num_features = NUM_FEATURES,num_classes  = NUM_CLASSES, num_hidden_1 = NUM_HIDDEN_1,num_hidden_2 = NUM_HIDDEN_2) 
    #model = ONELayerNN(num_features = NUM_FEATURES,num_classes  = NUM_CLASSES, num_hidden_1 = NUM_HIDDEN_1) 
    model.to(device)
    model.apply(initialize_weights)

    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE,weight_decay=WEIGHT_DECAY)
    criterion = nn.BCEWithLogitsLoss()
    # train & test process
    def train(trainloader,epoch,accuracy,dataloader_id):
        model.train()
        correct = 0
        for batch_idx, (data, target) in enumerate(trainloader):
            data, target = data.float().to(device), target.float().to(device)
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            store_loss(loss,data,trainloader,running_loss,epoch,dataloader_id) # loss for plotting
            pred = (output >= 0.5).type(torch.uint8)
            store_metrics(pred,target,trainloader,epoch,dataloader_id)
            correct += pred.eq(target.view_as(pred)).sum().item()   
            loss.backward()
            optimizer.step()

        train_acc = 100. * correct / len(trainloader.dataset)
        training_accuracy_dict[(epoch)] = train_acc
        #store_accuracy(pred,target,correct_store,trainloader,epoch,accuracy,dataloader_id) # accuracy for plotting

    def test(testloader,epoch,accuracy,dataloader_id):
        model.eval()
        correct = 0
        targets, preds = [], []
        with torch.no_grad():
            for data, target in test_loader:
                data, target = data.float().to(device), target.float().to(device)
                output = model(data)
                loss = criterion(output , target)
                store_loss(loss,data,test_loader,running_loss,epoch,dataloader_id) # loss for plotting
                pred = (output >= 0.5).type(torch.uint8) 
                store_metrics(pred,target,testloader,epoch,dataloader_id)
                correct += pred.eq(target.view_as(pred)).sum().item()
                targets += list(target.cpu().numpy())
                preds += list(pred.cpu().numpy())
        
        #store_accuracy(pred,target,correct_store,trainloader,epoch,accuracy,dataloader_id) # accuracy for plotting  
        test_acc = 100. * correct / len(testloader.dataset)
        validation_accuracy_dict[(epoch)] = test_acc
        confusion_mtx = sm.confusion_matrix(targets, preds)
        return test_acc, confusion_mtx
    
    test_accs, confusion_mtxes = [], []
    trainloader_id = train_loader.__hash__()    
    for epoch in range(1, NUM_EPOCHS + 1):
        running_loss = 0.0
        accuracy = 0
        train(train_loader,epoch,accuracy,trainloader_id)
        test_acc, confusion_mtx = test(test_loader,epoch,accuracy,trainloader_id)
        test_accs.append(test_acc)
        confusion_mtxes.append(confusion_mtx)
        print('\rBest test acc = %2.2f%%' % max(test_accs), end='', flush=True)

# %%
trainTestModel(train_loader=trainloader,test_loader=testloader)
# Out:
# Best test acc = 56.56%

# %%
# Create lists
train_accuracy_list = list(training_accuracy_dict.values())
test_accuracy_list = list(validation_accuracy_dict.values())

train_loss_list = list(training_loss_dict.values())
test_loss_list = list(validation_loss_dict.values())

train_precision_list = list(train_precision_dict.values()) 
train_recall_list = list(train_recall_dict.values()) 

train_f1_list = list(train_f1_dict.values())
train_mse_list = list(train_mse_dict.values())

test_precision_list = list(test_precision_dict.values()) 
test_recall_list = list(test_recall_dict.values()) 
test_f1_list = list(test_f1_dict.values())
test_mse_list = list(test_mse_dict.values())

# %%
print(f'avg train acc: {np.mean(train_accuracy_list):.2f} | 'f'avg test acc : {np.mean(test_accuracy_list):.2f} | '
      f'avg train prec : {np.mean(train_precision_list):.2f} |'f'avg test prec : {np.mean(test_precision_list):.2f} |'
      f' avg train mse: {np.mean(train_mse_list):.2f} | ' f'avg test mse: {np.mean(test_mse_list):.2f} |'
      f' avg train F1: {np.mean(train_f1_list):.2f} | 'f' avg test F1: {np.mean(test_f1_list):.2f}')
# Out:
# avg train acc: 57.02 | avg test acc : 52.02 | avg train prec : 0.49 |avg test prec : 0.36 | avg train mse: 0.43 | avg test mse: 0.48 | avg train F1: 0.46 |  avg test F1: 0.28

# %%
from tueplots import axes, bundles , figsizes, fonts,fontsizes
# Create plots of all metrics 

# Global plot settings 

fig, ax = plt.subplots(nrows=2, ncols=3,figsize=(12,4))
plt.rcParams.update({"figure.dpi": 150})
plt.rcParams.update(bundles.neurips2022())
plt.rcParams.update(fonts.neurips2022())
plt.rcParams.update(axes.tick_direction( y="in",x = "in"))
plt.rcParams.update(axes.color(base="black"))
plt.rcParams.update(figsizes.neurips2022(nrows=2, ncols=3))
plt.rcParams.update(fontsizes.neurips2022())


#x-axis
xrange = range(0,NUM_EPOCHS+1)

# Loss
ax[0,0].plot(range(0,len(train_loss_list)-1), train_loss_list[:-1], label='Train',color='magenta')
ax[0,0].plot(range(0,len(test_loss_list)-1), test_loss_list[:-1], label='Test',color = 'darkgreen')
ax[0,0].legend()
ax[0,0].set_xlabel('Epoch')
ax[0,0].set_ylabel('Loss')
ax[0,0].set_title(' Loss')

# Precison 
ax[0,1].plot(range(0,len(train_precision_list)), train_precision_list, label='Train ',color='magenta')
ax[0,1].plot(range(0,len(test_precision_list)), test_precision_list, label='Test ',color = 'darkgreen')
ax[0,1].set_xlabel('Epoch')
ax[0,1].set_ylabel('Precision')
ax[0,1].set_title(' Loss')
ax[0,1].set_title(' Precision')
ax[0,1].legend()
# F1 
ax[0,2].plot(range(0,len(train_f1_list)), train_f1_list, label='Train',color='magenta')
ax[0,2].plot(range(0,len(test_f1_list)), test_f1_list, label='Test',color = 'darkgreen')
ax[0,2].set_xlabel('Epoch')
ax[0,2].set_ylabel('F1')
ax[0,2].set_title(' Loss')
ax[0,2].set_title(' F1 Score ')
ax[0,2].legend()
# Accuracy 
ax[1,0].plot(range(0,len(train_accuracy_list)), train_accuracy_list, label='Train',color='magenta')
ax[1,0].plot(range(0,len(test_accuracy_list)), test_accuracy_list, label='Test',color = 'darkgreen')
ax[1,0].set_xlabel('Epoch')
ax[1,0].set_ylabel('Accuracy')
ax[1,0].set_title(' Accurary')
ax[1,0].legend()
# MSE
ax[1,1].plot(range(0,len(train_mse_list)), train_mse_list, label='Train',color='magenta')
ax[1,1].plot(range(0,len(test_mse_list)), test_mse_list, label='Test',color = 'darkgreen')
ax[1,1].set_xlabel('Epoch')
ax[1,1].set_ylabel('mse')
ax[1,1].set_title(' mean-squared error')
ax[1,1].legend()
# recall
ax[1,2].plot(range(0,len(train_recall_list)), train_recall_list, label='Train',color='magenta')
ax[1,2].plot(range(0,len(test_recall_list)), test_recall_list, label='Test',color = 'darkgreen')
ax[1,2].set_xlabel('Epoch')
ax[1,2].set_ylabel('recall')
ax[1,2].set_title(' Recall')
ax[1,2].legend()

# %%
fig, ax = plt.subplots(figsize=(12,4))

ax.set_facecolor('gainsboro')
# Set boarder colour 
for spine in ax.spines:
    ax.spines[spine].set_color('black')
    ax.spines[spine].set_linewidth(1)

ax.grid(color='white', axis='x', linestyle='-', linewidth=1, alpha=0.5)
ax.grid(color='white', axis='y', linestyle='-', linewidth=1, alpha=0.5)

epochs_train = len(train_accuracy_list)
epochs_val = len(test_accuracy_list)

plt.plot(np.arange(1, epochs_train+1),train_accuracy_list, label='Training',color='magenta')
plt.plot(np.arange(1, epochs_val+1),test_accuracy_list, label='Validation',color='darkgreen')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot training and validation losses 

# Use to plots to clean up the presentation 
from tueplots import bundles 
from tueplots import figsizes
from tueplots import axes

# tueplots paramaters 
plt.rcParams.update(bundles.neurips2022())
plt.rcParams.update(axes.lines())
figsizes.neurips2021(nrows=3)["figure.figsize"]

plt.rcParams.update({"figure.dpi": 150})

fig, ax = plt.subplots(figsize=(12,4))

ax.set_facecolor('gainsboro')
# Set boarder colour 
for spine in ax.spines:
    ax.spines[spine].set_color('black')
    ax.spines[spine].set_linewidth(1)

ax.grid(color='white', axis='x', linestyle='-', linewidth=1, alpha=0.5)
ax.grid(color='white', axis='y', linestyle='-', linewidth=1, alpha=0.5)

ax.plot(train_loss_list[:-1], label='Training loss',color='magenta')
ax.plot(test_loss_list[:-1], label='Validation loss',color = 'darkgreen')

ax.set_title(' Training and validation loss ')

ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')

ax.legend()


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:2801, in Figure.draw(self, renderer)
#    2799 renderer.open_group('figure', gid=self.get_gid())
#    2800 if self.get_constrained_layout() and self.axes:
# -> 2801     self.execute_constrained_layout(renderer)
#    2802 if self.get_tight_layout() and self.axes:
#    2803     try:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:3159, in Figure.execute_constrained_layout(self, renderer)
#    3157 if renderer is None:
#    3158     renderer = _get_renderer(fig)
# -> 3159 return do_constrained_layout(fig, renderer, h_pad, w_pad,
#    3160                              hspace, wspace)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/_constrained_layout.py:110, in do_constrained_layout(fig, renderer, h_pad, w_pad, hspace, wspace)
#     100     return
#     102 for _ in range(2):
#     103     # do the algorithm twice.  This has to be done because decorations
#     104     # change size after the first re-position (i.e. x/yticklabels get
#    (...)
#     108     # make margins for all the axes and subfigures in the
#     109     # figure.  Add margins for colorbars...
# --> 110     make_layout_margins(layoutgrids, fig, renderer, h_pad=h_pad,
#     111                         w_pad=w_pad, hspace=hspace, wspace=wspace)
#     112     make_margin_suptitles(layoutgrids, fig, renderer, h_pad=h_pad,
#     113                           w_pad=w_pad)
#     115     # if a layout is such that a columns (or rows) margin has no
#     116     # constraints, we need to make all such instances in the grid
#     117     # match in margin size.
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/_constrained_layout.py:313, in make_layout_margins(layoutgrids, fig, renderer, w_pad, h_pad, hspace, wspace)
#     309     return
#     311 margin = get_margin_from_padding(ax, w_pad=w_pad, h_pad=h_pad,
#     312                                  hspace=hspace, wspace=wspace)
# --> 313 pos, bbox = get_pos_and_bbox(ax, renderer)
#     314 # the margin is the distance between the bounding box of the axes
#     315 # and its position (plus the padding from above)
#     316 margin['left'] += pos.x0 - bbox.x0
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/_constrained_layout.py:544, in get_pos_and_bbox(ax, renderer)
#     542 pos = pos.transformed(fig.transSubfigure - fig.transFigure)
#     543 try:
# --> 544     tightbbox = ax.get_tightbbox(renderer=renderer, for_layout_only=True)
#     545 except TypeError:
#     546     tightbbox = ax.get_tightbbox(renderer=renderer)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py:4619, in _AxesBase.get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4617 if self.xaxis.get_visible():
#    4618     try:
# -> 4619         bb_xaxis = self.xaxis.get_tightbbox(
#    4620             renderer, for_layout_only=for_layout_only)
#    4621     except TypeError:
#    4622         # in case downstream library has redefined axis:
#    4623         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:1105, in Axis.get_tightbbox(self, renderer, for_layout_only)
#    1101     return
#    1103 ticks_to_draw = self._update_ticks()
# -> 1105 self._update_label_position(renderer)
#    1107 # go back to just this axis's tick labels
#    1108 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1109             ticks_to_draw, renderer)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:2083, in XAxis._update_label_position(self, renderer)
#    2079     return
#    2081 # get bounding boxes for this axis and any siblings
#    2082 # that have been set by `fig.align_xlabels()`
# -> 2083 bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2085 x, y = self.label.get_position()
#    2086 if self.label_position == 'bottom':
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:1881, in Axis._get_tick_boxes_siblings(self, renderer)
#    1879 axis = getattr(ax, f"{axis_name}axis")
#    1880 ticks_to_draw = axis._update_ticks()
# -> 1881 tlb, tlb2 = axis._get_tick_bboxes(ticks_to_draw, renderer)
#    1882 bboxes.extend(tlb)
#    1883 bboxes2.extend(tlb2)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:1085, in Axis._get_tick_bboxes(self, ticks, renderer)
#    1083 def _get_tick_bboxes(self, ticks, renderer):
#    1084     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085     return ([tick.label1.get_window_extent(renderer)
#    1086              for tick in ticks if tick.label1.get_visible()],
#    1087             [tick.label2.get_window_extent(renderer)
#    1088              for tick in ticks if tick.label2.get_visible()])
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axis.py:1085, in <listcomp>(.0)
#    1083 def _get_tick_bboxes(self, ticks, renderer):
#    1084     """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1085     return ([tick.label1.get_window_extent(renderer)
#    1086              for tick in ticks if tick.label1.get_visible()],
#    1087             [tick.label2.get_window_extent(renderer)
#    1088              for tick in ticks if tick.label2.get_visible()])
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/text.py:910, in Text.get_window_extent(self, renderer, dpi)
#     907     raise RuntimeError('Cannot get window extent w/o renderer')
#     909 with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 910     bbox, info, descent = self._get_layout(self._renderer)
#     911     x, y = self.get_unitless_position()
#     912     x, y = self.get_transform().transform((x, y))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/text.py:309, in Text._get_layout(self, renderer)
#     306 ys = []
#     308 # Full vertical extent of font, including ascenders and descenders:
# --> 309 _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     310     "lp", self._fontproperties,
#     311     ismath="TeX" if self.get_usetex() else False)
#     312 min_dy = (lp_h - lp_d) * self._linespacing
#     314 for i, line in enumerate(lines):
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:259, in RendererAgg.get_text_width_height_descent(self, s, prop, ismath)
#     257     texmanager = self.get_texmanager()
#     258     fontsize = prop.get_size_in_points()
# --> 259     w, h, d = texmanager.get_text_width_height_descent(
#     260         s, fontsize, renderer=self)
#     261     return w, h, d
#     263 if ismath:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/texmanager.py:338, in TexManager.get_text_width_height_descent(self, tex, fontsize, renderer)
#     336 dpi_fraction = renderer.points_to_pixels(1.) if renderer else 1
#     337 with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
# --> 338     page, = dvi
#     339 # A total height (including the descent) needs to be returned.
#     340 return page.width, page.height + page.descent, page.descent
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dviread.py:237, in Dvi.__iter__(self)
#     221 def __iter__(self):
#     222     """
#     223     Iterate through the pages of the file.
#     224
#    (...)
#     235         integers.
#     236     """
# --> 237     while self._read():
#     238         yield self._output()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dviread.py:316, in Dvi._read(self)
#     314 while True:
#     315     byte = self.file.read(1)[0]
# --> 316     self._dtable[byte](self, byte)
#     317     name = self._dtable[byte].__name__
#     318     if name == "_push":
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dviread.py:166, in _dispatch.<locals>.decorate.<locals>.wrapper(self, byte)
#     164 if state is not None and self.state != state:
#     165     raise ValueError("state precondition failed")
# --> 166 return method(self, *[f(self, byte-min) for f in get_args])
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dviread.py:467, in Dvi._fnt_def(self, k, c, s, d, a, l)
#     465 @_dispatch(min=243, max=246, args=('olen1', 'u4', 'u4', 'u4', 'u1', 'u1'))
#     466 def _fnt_def(self, k, c, s, d, a, l):
# --> 467     self._fnt_def_real(k, c, s, d, a, l)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/dviread.py:474, in Dvi._fnt_def_real(self, k, c, s, d, a, l)
#     472 tfm = _tfmfile(fontname)
#     473 if tfm is None:
# --> 474     raise FileNotFoundError("missing font metrics file: %s" % fontname)
#     475 if c != 0 and tfm.checksum != 0 and c != tfm.checksum:
#     476     raise ValueError('tfm checksum mismatch: %s' % n)
#
# FileNotFoundError: missing font metrics file: ptmr7t
